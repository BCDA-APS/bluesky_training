# %% [markdown]
# # move data from one db to another
#
# see: https://github.com/APS-3ID-IXN/ipython-s3blue/issues/2

# %% [markdown]
# the packages we'll be using

# %%
from databroker import Broker
import datetime, os, shutil, time
import pyRestTable

# %% [markdown]
# connect to the database where scans were collected

# %%
server = "otz"
otz_config = {
    "description": "heavyweight shared database",
    "metadatastore": {
        "module": "databroker.headersource.mongo",
        "class": "MDS",
        "config": {
            "host": server,
            "port": 27017,
            "database": "metadatastore-production-v1",
            "timezone": "US/Central"
        }
    },
    "assets": {
        "module": "databroker.assets.mongo",
        "class": "Registry",
        "config": {
            "host": server,
            "port": 27017,
            "database": "filestore-production-v1"
        }
    }
}
otz_db = Broker.from_config(otz_config)

# %% [markdown]
# Show the scans between the dates mentioned in the [issue](https://github.com/APS-3ID-IXN/ipython-s3blue/issues/2)

# %%
headers = otz_db(since='2018-10-20', until='2018-11-06')
for h in headers:
    print(h.start)
# Out:
# Run Start
# =========
# BLUESKY_VERSION : 1.3.3
# EPICS_AR_PORT   : 7002
# EPICS_CA_MAX_ARR: 16777216
# EPICS_EXTENSIONS: /APSshare/epics/extensions
# EPICS_HOST_ARCH : linux-x86_64
# OPHYD_VERSION   : 1.2.0
# beamline_id     : 3-ID
# detectors       : ['mca', 'scaler']
# extents         : [[0, 0], [-0.0005, 0.0005]]
# hints           :
#   gridding        : rectilinear
#   dimensions      : [[['neat_stage_y'], 'primary'], [['neat_stage_x'], 'primary']]
# login_id        : s3blue@ni.xray.aps.anl.gov
# motors          : ['neat_stage_y', 'neat_stage_x']
# num_intervals   : 9
# num_points      : 10
# pid             : 28587
# plan_args       :
#   detectors       : ["EpicsMCA(prefix='3ida:mca1', name='mca', read_attrs=['preset_real_time', 'elapsed_real_time', 'spectrum'], configuration_attrs=['preset_real_time'])", "ScalerCH(prefix='3idb:scaler1', name='scaler', read_attrs=['channels', 'channels.chan01', 'channels.chan01.s', 'channels.chan02', 'channels.chan02.s', 'channels.chan03', 'channels.chan03.s', 'channels.chan04', 'channels.chan04.s', 'channels.chan05', 'channels.chan05.s', 'channels.chan06', 'channels.chan06.s', 'channels.chan07', 'channels.chan07.s', 'channels.chan08', 'channels.chan08.s', 'time'], configuration_attrs=['channels', 'channels.chan01', 'channels.chan01.chname', 'channels.chan01.preset', 'channels.chan01.gate', 'channels.chan02', 'channels.chan02.chname', 'channels.chan02.preset', 'channels.chan02.gate', 'channels.chan03', 'channels.chan03.chname', 'channels.chan03.preset', 'channels.chan03.gate', 'channels.chan04', 'channels.chan04.chname', 'channels.chan04.preset', 'channels.chan04.gate', 'channels.chan05', 'channels.chan05.chname', 'channels.chan05.preset', 'channels.chan05.gate', 'channels.chan06', 'channels.chan06.chname', 'channels.chan06.preset', 'channels.chan06.gate', 'channels.chan07', 'channels.chan07.chname', 'channels.chan07.preset', 'channels.chan07.gate', 'channels.chan08', 'channels.chan08.chname', 'channels.chan08.preset', 'channels.chan08.gate', 'channels.chan09', 'channels.chan09.chname', 'channels.chan09.preset', 'channels.chan09.gate', 'channels.chan10', 'channels.chan10.chname', 'channels.chan10.preset', 'channels.chan10.gate', 'channels.chan11', 'channels.chan11.chname', 'channels.chan11.preset', 'channels.chan11.gate', 'channels.chan12', 'channels.chan12.chname', 'channels.chan12.preset', 'channels.chan12.gate', 'channels.chan13', 'channels.chan13.chname', 'channels.chan13.preset', 'channels.chan13.gate', 'channels.chan14', 'channels.chan14.chname', 'channels.chan14.preset', 'channels.chan14.gate', 'channels.chan15', 'channels.chan15.chname', 'channels.chan15.preset', 'channels.chan15.gate', 'channels.chan16', 'channels.chan16.chname', 'channels.chan16.preset', 'channels.chan16.gate', 'channels.chan17', 'channels.chan17.chname', 'channels.chan17.preset', 'channels.chan17.gate', 'channels.chan18', 'channels.chan18.chname', 'channels.chan18.preset', 'channels.chan18.gate', 'channels.chan19', 'channels.chan19.chname', 'channels.chan19.preset', 'channels.chan19.gate', 'channels.chan20', 'channels.chan20.chname', 'channels.chan20.preset', 'channels.chan20.gate', 'channels.chan21', 'channels.chan21.chname', 'channels.chan21.preset', 'channels.chan21.gate', 'channels.chan22', 'channels.chan22.chname', 'channels.chan22.preset', 'channels.chan22.gate', 'channels.chan23', 'channels.chan23.chname', 'channels.chan23.preset', 'channels.chan23.gate', 'channels.chan24', 'channels.chan24.chname', 'channels.chan24.preset', 'channels.chan24.gate', 'channels.chan25', 'channels.chan25.chname', 'channels.chan25.preset', 'channels.chan25.gate', 'channels.chan26', 'channels.chan26.chname', 'channels.chan26.preset', 'channels.chan26.gate', 'channels.chan27', 'channels.chan27.chname', 'channels.chan27.preset', 'channels.chan27.gate', 'channels.chan28', 'channels.chan28.chname', 'channels.chan28.preset', 'channels.chan28.gate', 'channels.chan29', 'channels.chan29.chname', 'channels.chan29.preset', 'channels.chan29.gate', 'channels.chan30', 'channels.chan30.chname', 'channels.chan30.preset', 'channels.chan30.gate', 'channels.chan31', 'channels.chan31.chname', 'channels.chan31.preset', 'channels.chan31.gate', 'channels.chan32', 'channels.chan32.chname', 'channels.chan32.preset', 'channels.chan32.gate', 'count_mode', 'delay', 'auto_count_delay', 'freq', 'preset_time', 'auto_count_time', 'egu'])"]
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.0005, 0.0005, 10, False]
#   per_step        : <function optimize_energy_per_step at 0x7f3e38557158>
# plan_name       : rel_grid_scan
# plan_pattern    : outer_product
# plan_pattern_args:
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.0005, 0.0005, 10, False]
# plan_pattern_mod: bluesky.plan_patterns
# plan_type       : generator
# proposal_id     : None
# sample_name     : Paris_B1
# scan_id         : 48
# shape           : [1, 10]
# snaking         : [False, False]
# time            : 1540802724.1678064
# uid             : 6ea22d45-7b57-4936-b007-a6129a04a28c
#
# Run Start
# =========
# BLUESKY_VERSION : 1.3.3
# EPICS_AR_PORT   : 7002
# EPICS_CA_MAX_ARR: 16777216
# EPICS_EXTENSIONS: /APSshare/epics/extensions
# EPICS_HOST_ARCH : linux-x86_64
# OPHYD_VERSION   : 1.2.0
# beamline_id     : 3-ID
# detectors       : ['mca', 'scaler']
# extents         : [[0, 0], [-0.0005, 0.0005]]
# hints           :
#   gridding        : rectilinear
#   dimensions      : [[['neat_stage_y'], 'primary'], [['neat_stage_x'], 'primary']]
# login_id        : s3blue@ni.xray.aps.anl.gov
# motors          : ['neat_stage_y', 'neat_stage_x']
# num_intervals   : 9
# num_points      : 10
# pid             : 28587
# plan_args       :
#   detectors       : ["EpicsMCA(prefix='3ida:mca1', name='mca', read_attrs=['preset_real_time', 'elapsed_real_time', 'spectrum'], configuration_attrs=['preset_real_time'])", "ScalerCH(prefix='3idb:scaler1', name='scaler', read_attrs=['channels', 'channels.chan01', 'channels.chan01.s', 'channels.chan02', 'channels.chan02.s', 'channels.chan03', 'channels.chan03.s', 'channels.chan04', 'channels.chan04.s', 'channels.chan05', 'channels.chan05.s', 'channels.chan06', 'channels.chan06.s', 'channels.chan07', 'channels.chan07.s', 'channels.chan08', 'channels.chan08.s', 'time'], configuration_attrs=['channels', 'channels.chan01', 'channels.chan01.chname', 'channels.chan01.preset', 'channels.chan01.gate', 'channels.chan02', 'channels.chan02.chname', 'channels.chan02.preset', 'channels.chan02.gate', 'channels.chan03', 'channels.chan03.chname', 'channels.chan03.preset', 'channels.chan03.gate', 'channels.chan04', 'channels.chan04.chname', 'channels.chan04.preset', 'channels.chan04.gate', 'channels.chan05', 'channels.chan05.chname', 'channels.chan05.preset', 'channels.chan05.gate', 'channels.chan06', 'channels.chan06.chname', 'channels.chan06.preset', 'channels.chan06.gate', 'channels.chan07', 'channels.chan07.chname', 'channels.chan07.preset', 'channels.chan07.gate', 'channels.chan08', 'channels.chan08.chname', 'channels.chan08.preset', 'channels.chan08.gate', 'channels.chan09', 'channels.chan09.chname', 'channels.chan09.preset', 'channels.chan09.gate', 'channels.chan10', 'channels.chan10.chname', 'channels.chan10.preset', 'channels.chan10.gate', 'channels.chan11', 'channels.chan11.chname', 'channels.chan11.preset', 'channels.chan11.gate', 'channels.chan12', 'channels.chan12.chname', 'channels.chan12.preset', 'channels.chan12.gate', 'channels.chan13', 'channels.chan13.chname', 'channels.chan13.preset', 'channels.chan13.gate', 'channels.chan14', 'channels.chan14.chname', 'channels.chan14.preset', 'channels.chan14.gate', 'channels.chan15', 'channels.chan15.chname', 'channels.chan15.preset', 'channels.chan15.gate', 'channels.chan16', 'channels.chan16.chname', 'channels.chan16.preset', 'channels.chan16.gate', 'channels.chan17', 'channels.chan17.chname', 'channels.chan17.preset', 'channels.chan17.gate', 'channels.chan18', 'channels.chan18.chname', 'channels.chan18.preset', 'channels.chan18.gate', 'channels.chan19', 'channels.chan19.chname', 'channels.chan19.preset', 'channels.chan19.gate', 'channels.chan20', 'channels.chan20.chname', 'channels.chan20.preset', 'channels.chan20.gate', 'channels.chan21', 'channels.chan21.chname', 'channels.chan21.preset', 'channels.chan21.gate', 'channels.chan22', 'channels.chan22.chname', 'channels.chan22.preset', 'channels.chan22.gate', 'channels.chan23', 'channels.chan23.chname', 'channels.chan23.preset', 'channels.chan23.gate', 'channels.chan24', 'channels.chan24.chname', 'channels.chan24.preset', 'channels.chan24.gate', 'channels.chan25', 'channels.chan25.chname', 'channels.chan25.preset', 'channels.chan25.gate', 'channels.chan26', 'channels.chan26.chname', 'channels.chan26.preset', 'channels.chan26.gate', 'channels.chan27', 'channels.chan27.chname', 'channels.chan27.preset', 'channels.chan27.gate', 'channels.chan28', 'channels.chan28.chname', 'channels.chan28.preset', 'channels.chan28.gate', 'channels.chan29', 'channels.chan29.chname', 'channels.chan29.preset', 'channels.chan29.gate', 'channels.chan30', 'channels.chan30.chname', 'channels.chan30.preset', 'channels.chan30.gate', 'channels.chan31', 'channels.chan31.chname', 'channels.chan31.preset', 'channels.chan31.gate', 'channels.chan32', 'channels.chan32.chname', 'channels.chan32.preset', 'channels.chan32.gate', 'count_mode', 'delay', 'auto_count_delay', 'freq', 'preset_time', 'auto_count_time', 'egu'])"]
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.0005, 0.0005, 10, False]
#   per_step        : <function optimize_energy_per_step at 0x7f3e38557158>
# plan_name       : rel_grid_scan
# plan_pattern    : outer_product
# plan_pattern_args:
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.0005, 0.0005, 10, False]
# plan_pattern_mod: bluesky.plan_patterns
# plan_type       : generator
# proposal_id     : None
# sample_name     : Paris
# scan_id         : 47
# shape           : [1, 10]
# snaking         : [False, False]
# time            : 1540770960.852009
# uid             : b7f9a22f-bff3-4fca-8223-3fe3c13cf04a
#
# Run Start
# =========
# BLUESKY_VERSION : 1.3.3
# EPICS_AR_PORT   : 7002
# EPICS_CA_MAX_ARR: 16777216
# EPICS_EXTENSIONS: /APSshare/epics/extensions
# EPICS_HOST_ARCH : linux-x86_64
# OPHYD_VERSION   : 1.2.0
# beamline_id     : 3-ID
# detectors       : ['mca', 'scaler']
# extents         : [[0, 0], [-0.0005, 0.0005]]
# hints           :
#   gridding        : rectilinear
#   dimensions      : [[['neat_stage_y'], 'primary'], [['neat_stage_x'], 'primary']]
# login_id        : s3blue@ni.xray.aps.anl.gov
# motors          : ['neat_stage_y', 'neat_stage_x']
# num_intervals   : 9
# num_points      : 10
# pid             : 28587
# plan_args       :
#   detectors       : ["EpicsMCA(prefix='3ida:mca1', name='mca', read_attrs=['preset_real_time', 'elapsed_real_time', 'spectrum'], configuration_attrs=['preset_real_time'])", "ScalerCH(prefix='3idb:scaler1', name='scaler', read_attrs=['channels', 'channels.chan01', 'channels.chan01.s', 'channels.chan02', 'channels.chan02.s', 'channels.chan03', 'channels.chan03.s', 'channels.chan04', 'channels.chan04.s', 'channels.chan05', 'channels.chan05.s', 'channels.chan06', 'channels.chan06.s', 'channels.chan07', 'channels.chan07.s', 'channels.chan08', 'channels.chan08.s', 'time'], configuration_attrs=['channels', 'channels.chan01', 'channels.chan01.chname', 'channels.chan01.preset', 'channels.chan01.gate', 'channels.chan02', 'channels.chan02.chname', 'channels.chan02.preset', 'channels.chan02.gate', 'channels.chan03', 'channels.chan03.chname', 'channels.chan03.preset', 'channels.chan03.gate', 'channels.chan04', 'channels.chan04.chname', 'channels.chan04.preset', 'channels.chan04.gate', 'channels.chan05', 'channels.chan05.chname', 'channels.chan05.preset', 'channels.chan05.gate', 'channels.chan06', 'channels.chan06.chname', 'channels.chan06.preset', 'channels.chan06.gate', 'channels.chan07', 'channels.chan07.chname', 'channels.chan07.preset', 'channels.chan07.gate', 'channels.chan08', 'channels.chan08.chname', 'channels.chan08.preset', 'channels.chan08.gate', 'channels.chan09', 'channels.chan09.chname', 'channels.chan09.preset', 'channels.chan09.gate', 'channels.chan10', 'channels.chan10.chname', 'channels.chan10.preset', 'channels.chan10.gate', 'channels.chan11', 'channels.chan11.chname', 'channels.chan11.preset', 'channels.chan11.gate', 'channels.chan12', 'channels.chan12.chname', 'channels.chan12.preset', 'channels.chan12.gate', 'channels.chan13', 'channels.chan13.chname', 'channels.chan13.preset', 'channels.chan13.gate', 'channels.chan14', 'channels.chan14.chname', 'channels.chan14.preset', 'channels.chan14.gate', 'channels.chan15', 'channels.chan15.chname', 'channels.chan15.preset', 'channels.chan15.gate', 'channels.chan16', 'channels.chan16.chname', 'channels.chan16.preset', 'channels.chan16.gate', 'channels.chan17', 'channels.chan17.chname', 'channels.chan17.preset', 'channels.chan17.gate', 'channels.chan18', 'channels.chan18.chname', 'channels.chan18.preset', 'channels.chan18.gate', 'channels.chan19', 'channels.chan19.chname', 'channels.chan19.preset', 'channels.chan19.gate', 'channels.chan20', 'channels.chan20.chname', 'channels.chan20.preset', 'channels.chan20.gate', 'channels.chan21', 'channels.chan21.chname', 'channels.chan21.preset', 'channels.chan21.gate', 'channels.chan22', 'channels.chan22.chname', 'channels.chan22.preset', 'channels.chan22.gate', 'channels.chan23', 'channels.chan23.chname', 'channels.chan23.preset', 'channels.chan23.gate', 'channels.chan24', 'channels.chan24.chname', 'channels.chan24.preset', 'channels.chan24.gate', 'channels.chan25', 'channels.chan25.chname', 'channels.chan25.preset', 'channels.chan25.gate', 'channels.chan26', 'channels.chan26.chname', 'channels.chan26.preset', 'channels.chan26.gate', 'channels.chan27', 'channels.chan27.chname', 'channels.chan27.preset', 'channels.chan27.gate', 'channels.chan28', 'channels.chan28.chname', 'channels.chan28.preset', 'channels.chan28.gate', 'channels.chan29', 'channels.chan29.chname', 'channels.chan29.preset', 'channels.chan29.gate', 'channels.chan30', 'channels.chan30.chname', 'channels.chan30.preset', 'channels.chan30.gate', 'channels.chan31', 'channels.chan31.chname', 'channels.chan31.preset', 'channels.chan31.gate', 'channels.chan32', 'channels.chan32.chname', 'channels.chan32.preset', 'channels.chan32.gate', 'count_mode', 'delay', 'auto_count_delay', 'freq', 'preset_time', 'auto_count_time', 'egu'])"]
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.0005, 0.0005, 10, False]
#   per_step        : <function optimize_energy_per_step at 0x7f3e38557158>
# plan_name       : rel_grid_scan
# plan_pattern    : outer_product
# plan_pattern_args:
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.0005, 0.0005, 10, False]
# plan_pattern_mod: bluesky.plan_patterns
# plan_type       : generator
# proposal_id     : None
# sample_name     : Paris
# scan_id         : 46
# shape           : [1, 10]
# snaking         : [False, False]
# time            : 1540770266.5944276
# uid             : ab52f840-7919-4925-8c62-790a0bf629ef
#
# Run Start
# =========
# BLUESKY_VERSION : 1.3.3
# EPICS_AR_PORT   : 7002
# EPICS_CA_MAX_ARR: 16777216
# EPICS_EXTENSIONS: /APSshare/epics/extensions
# EPICS_HOST_ARCH : linux-x86_64
# OPHYD_VERSION   : 1.2.0
# beamline_id     : 3-ID
# detectors       : ['mca', 'scaler']
# extents         : [[0, 0], [-0.05, 0.05]]
# hints           :
#   gridding        : rectilinear
#   dimensions      : [[['neat_stage_y'], 'primary'], [['neat_stage_x'], 'primary']]
# login_id        : s3blue@ni.xray.aps.anl.gov
# motors          : ['neat_stage_y', 'neat_stage_x']
# num_intervals   : 2
# num_points      : 3
# pid             : 28587
# plan_args       :
#   detectors       : ["EpicsMCA(prefix='3ida:mca1', name='mca', read_attrs=['preset_real_time', 'elapsed_real_time', 'spectrum'], configuration_attrs=['preset_real_time'])", "ScalerCH(prefix='3idb:scaler1', name='scaler', read_attrs=['channels', 'channels.chan01', 'channels.chan01.s', 'channels.chan02', 'channels.chan02.s', 'channels.chan03', 'channels.chan03.s', 'channels.chan04', 'channels.chan04.s', 'channels.chan05', 'channels.chan05.s', 'channels.chan06', 'channels.chan06.s', 'channels.chan07', 'channels.chan07.s', 'channels.chan08', 'channels.chan08.s', 'time'], configuration_attrs=['channels', 'channels.chan01', 'channels.chan01.chname', 'channels.chan01.preset', 'channels.chan01.gate', 'channels.chan02', 'channels.chan02.chname', 'channels.chan02.preset', 'channels.chan02.gate', 'channels.chan03', 'channels.chan03.chname', 'channels.chan03.preset', 'channels.chan03.gate', 'channels.chan04', 'channels.chan04.chname', 'channels.chan04.preset', 'channels.chan04.gate', 'channels.chan05', 'channels.chan05.chname', 'channels.chan05.preset', 'channels.chan05.gate', 'channels.chan06', 'channels.chan06.chname', 'channels.chan06.preset', 'channels.chan06.gate', 'channels.chan07', 'channels.chan07.chname', 'channels.chan07.preset', 'channels.chan07.gate', 'channels.chan08', 'channels.chan08.chname', 'channels.chan08.preset', 'channels.chan08.gate', 'channels.chan09', 'channels.chan09.chname', 'channels.chan09.preset', 'channels.chan09.gate', 'channels.chan10', 'channels.chan10.chname', 'channels.chan10.preset', 'channels.chan10.gate', 'channels.chan11', 'channels.chan11.chname', 'channels.chan11.preset', 'channels.chan11.gate', 'channels.chan12', 'channels.chan12.chname', 'channels.chan12.preset', 'channels.chan12.gate', 'channels.chan13', 'channels.chan13.chname', 'channels.chan13.preset', 'channels.chan13.gate', 'channels.chan14', 'channels.chan14.chname', 'channels.chan14.preset', 'channels.chan14.gate', 'channels.chan15', 'channels.chan15.chname', 'channels.chan15.preset', 'channels.chan15.gate', 'channels.chan16', 'channels.chan16.chname', 'channels.chan16.preset', 'channels.chan16.gate', 'channels.chan17', 'channels.chan17.chname', 'channels.chan17.preset', 'channels.chan17.gate', 'channels.chan18', 'channels.chan18.chname', 'channels.chan18.preset', 'channels.chan18.gate', 'channels.chan19', 'channels.chan19.chname', 'channels.chan19.preset', 'channels.chan19.gate', 'channels.chan20', 'channels.chan20.chname', 'channels.chan20.preset', 'channels.chan20.gate', 'channels.chan21', 'channels.chan21.chname', 'channels.chan21.preset', 'channels.chan21.gate', 'channels.chan22', 'channels.chan22.chname', 'channels.chan22.preset', 'channels.chan22.gate', 'channels.chan23', 'channels.chan23.chname', 'channels.chan23.preset', 'channels.chan23.gate', 'channels.chan24', 'channels.chan24.chname', 'channels.chan24.preset', 'channels.chan24.gate', 'channels.chan25', 'channels.chan25.chname', 'channels.chan25.preset', 'channels.chan25.gate', 'channels.chan26', 'channels.chan26.chname', 'channels.chan26.preset', 'channels.chan26.gate', 'channels.chan27', 'channels.chan27.chname', 'channels.chan27.preset', 'channels.chan27.gate', 'channels.chan28', 'channels.chan28.chname', 'channels.chan28.preset', 'channels.chan28.gate', 'channels.chan29', 'channels.chan29.chname', 'channels.chan29.preset', 'channels.chan29.gate', 'channels.chan30', 'channels.chan30.chname', 'channels.chan30.preset', 'channels.chan30.gate', 'channels.chan31', 'channels.chan31.chname', 'channels.chan31.preset', 'channels.chan31.gate', 'channels.chan32', 'channels.chan32.chname', 'channels.chan32.preset', 'channels.chan32.gate', 'count_mode', 'delay', 'auto_count_delay', 'freq', 'preset_time', 'auto_count_time', 'egu'])"]
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.05, 0.05, 3, False]
#   per_step        : <function optimize_energy_per_step at 0x7f3e38557158>
# plan_name       : rel_grid_scan
# plan_pattern    : outer_product
# plan_pattern_args:
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.05, 0.05, 3, False]
# plan_pattern_mod: bluesky.plan_patterns
# plan_type       : generator
# proposal_id     : None
# sample_name     : Murchison
# scan_id         : 45
# shape           : [1, 3]
# snaking         : [False, False]
# time            : 1540763951.5318148
# uid             : 8b318daa-c3ee-46d3-9d42-15c51f2e7598
#
# Run Start
# =========
# BLUESKY_VERSION : 1.3.3
# EPICS_AR_PORT   : 7002
# EPICS_CA_MAX_ARR: 16777216
# EPICS_EXTENSIONS: /APSshare/epics/extensions
# EPICS_HOST_ARCH : linux-x86_64
# OPHYD_VERSION   : 1.2.0
# beamline_id     : 3-ID
# detectors       : ['mca', 'scaler']
# extents         : [[0, 0], [-0.1, 0.1]]
# hints           :
#   gridding        : rectilinear
#   dimensions      : [[['neat_stage_y'], 'primary'], [['neat_stage_x'], 'primary']]
# login_id        : s3blue@ni.xray.aps.anl.gov
# motors          : ['neat_stage_y', 'neat_stage_x']
# num_intervals   : 2
# num_points      : 3
# pid             : 28587
# plan_args       :
#   detectors       : ["EpicsMCA(prefix='3ida:mca1', name='mca', read_attrs=['preset_real_time', 'elapsed_real_time', 'spectrum'], configuration_attrs=['preset_real_time'])", "ScalerCH(prefix='3idb:scaler1', name='scaler', read_attrs=['channels', 'channels.chan01', 'channels.chan01.s', 'channels.chan02', 'channels.chan02.s', 'channels.chan03', 'channels.chan03.s', 'channels.chan04', 'channels.chan04.s', 'channels.chan05', 'channels.chan05.s', 'channels.chan06', 'channels.chan06.s', 'channels.chan07', 'channels.chan07.s', 'channels.chan08', 'channels.chan08.s', 'time'], configuration_attrs=['channels', 'channels.chan01', 'channels.chan01.chname', 'channels.chan01.preset', 'channels.chan01.gate', 'channels.chan02', 'channels.chan02.chname', 'channels.chan02.preset', 'channels.chan02.gate', 'channels.chan03', 'channels.chan03.chname', 'channels.chan03.preset', 'channels.chan03.gate', 'channels.chan04', 'channels.chan04.chname', 'channels.chan04.preset', 'channels.chan04.gate', 'channels.chan05', 'channels.chan05.chname', 'channels.chan05.preset', 'channels.chan05.gate', 'channels.chan06', 'channels.chan06.chname', 'channels.chan06.preset', 'channels.chan06.gate', 'channels.chan07', 'channels.chan07.chname', 'channels.chan07.preset', 'channels.chan07.gate', 'channels.chan08', 'channels.chan08.chname', 'channels.chan08.preset', 'channels.chan08.gate', 'channels.chan09', 'channels.chan09.chname', 'channels.chan09.preset', 'channels.chan09.gate', 'channels.chan10', 'channels.chan10.chname', 'channels.chan10.preset', 'channels.chan10.gate', 'channels.chan11', 'channels.chan11.chname', 'channels.chan11.preset', 'channels.chan11.gate', 'channels.chan12', 'channels.chan12.chname', 'channels.chan12.preset', 'channels.chan12.gate', 'channels.chan13', 'channels.chan13.chname', 'channels.chan13.preset', 'channels.chan13.gate', 'channels.chan14', 'channels.chan14.chname', 'channels.chan14.preset', 'channels.chan14.gate', 'channels.chan15', 'channels.chan15.chname', 'channels.chan15.preset', 'channels.chan15.gate', 'channels.chan16', 'channels.chan16.chname', 'channels.chan16.preset', 'channels.chan16.gate', 'channels.chan17', 'channels.chan17.chname', 'channels.chan17.preset', 'channels.chan17.gate', 'channels.chan18', 'channels.chan18.chname', 'channels.chan18.preset', 'channels.chan18.gate', 'channels.chan19', 'channels.chan19.chname', 'channels.chan19.preset', 'channels.chan19.gate', 'channels.chan20', 'channels.chan20.chname', 'channels.chan20.preset', 'channels.chan20.gate', 'channels.chan21', 'channels.chan21.chname', 'channels.chan21.preset', 'channels.chan21.gate', 'channels.chan22', 'channels.chan22.chname', 'channels.chan22.preset', 'channels.chan22.gate', 'channels.chan23', 'channels.chan23.chname', 'channels.chan23.preset', 'channels.chan23.gate', 'channels.chan24', 'channels.chan24.chname', 'channels.chan24.preset', 'channels.chan24.gate', 'channels.chan25', 'channels.chan25.chname', 'channels.chan25.preset', 'channels.chan25.gate', 'channels.chan26', 'channels.chan26.chname', 'channels.chan26.preset', 'channels.chan26.gate', 'channels.chan27', 'channels.chan27.chname', 'channels.chan27.preset', 'channels.chan27.gate', 'channels.chan28', 'channels.chan28.chname', 'channels.chan28.preset', 'channels.chan28.gate', 'channels.chan29', 'channels.chan29.chname', 'channels.chan29.preset', 'channels.chan29.gate', 'channels.chan30', 'channels.chan30.chname', 'channels.chan30.preset', 'channels.chan30.gate', 'channels.chan31', 'channels.chan31.chname', 'channels.chan31.preset', 'channels.chan31.gate', 'channels.chan32', 'channels.chan32.chname', 'channels.chan32.preset', 'channels.chan32.gate', 'count_mode', 'delay', 'auto_count_delay', 'freq', 'preset_time', 'auto_count_time', 'egu'])"]
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.1, 0.1, 3, False]
#   per_step        : <function optimize_energy_per_step at 0x7f3e38557158>
# plan_name       : rel_grid_scan
# plan_pattern    : outer_product
# plan_pattern_args:
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.1, 0.1, 3, False]
# plan_pattern_mod: bluesky.plan_patterns
# plan_type       : generator
# proposal_id     : None
# sample_name     : test
# scan_id         : 44
# shape           : [1, 3]
# snaking         : [False, False]
# time            : 1540763610.9975512
# uid             : a4b7fd59-7875-489a-8a5f-1cc44f311760
#
# Run Start
# =========
# BLUESKY_VERSION : 1.3.3
# EPICS_AR_PORT   : 7002
# EPICS_CA_MAX_ARR: 16777216
# EPICS_EXTENSIONS: /APSshare/epics/extensions
# EPICS_HOST_ARCH : linux-x86_64
# OPHYD_VERSION   : 1.2.0
# beamline_id     : 3-ID
# detectors       : ['mca', 'scaler']
# extents         : [[0, 0], [-0.1, 0.1]]
# hints           :
#   gridding        : rectilinear
#   dimensions      : [[['neat_stage_y'], 'primary'], [['neat_stage_x'], 'primary']]
# login_id        : s3blue@ni.xray.aps.anl.gov
# motors          : ['neat_stage_y', 'neat_stage_x']
# num_intervals   : 2
# num_points      : 3
# pid             : 28587
# plan_args       :
#   detectors       : ["EpicsMCA(prefix='3ida:mca1', name='mca', read_attrs=['preset_real_time', 'elapsed_real_time', 'spectrum'], configuration_attrs=['preset_real_time'])", "ScalerCH(prefix='3idb:scaler1', name='scaler', read_attrs=['channels', 'channels.chan01', 'channels.chan01.s', 'channels.chan02', 'channels.chan02.s', 'channels.chan03', 'channels.chan03.s', 'channels.chan04', 'channels.chan04.s', 'channels.chan05', 'channels.chan05.s', 'channels.chan06', 'channels.chan06.s', 'channels.chan07', 'channels.chan07.s', 'channels.chan08', 'channels.chan08.s', 'time'], configuration_attrs=['channels', 'channels.chan01', 'channels.chan01.chname', 'channels.chan01.preset', 'channels.chan01.gate', 'channels.chan02', 'channels.chan02.chname', 'channels.chan02.preset', 'channels.chan02.gate', 'channels.chan03', 'channels.chan03.chname', 'channels.chan03.preset', 'channels.chan03.gate', 'channels.chan04', 'channels.chan04.chname', 'channels.chan04.preset', 'channels.chan04.gate', 'channels.chan05', 'channels.chan05.chname', 'channels.chan05.preset', 'channels.chan05.gate', 'channels.chan06', 'channels.chan06.chname', 'channels.chan06.preset', 'channels.chan06.gate', 'channels.chan07', 'channels.chan07.chname', 'channels.chan07.preset', 'channels.chan07.gate', 'channels.chan08', 'channels.chan08.chname', 'channels.chan08.preset', 'channels.chan08.gate', 'channels.chan09', 'channels.chan09.chname', 'channels.chan09.preset', 'channels.chan09.gate', 'channels.chan10', 'channels.chan10.chname', 'channels.chan10.preset', 'channels.chan10.gate', 'channels.chan11', 'channels.chan11.chname', 'channels.chan11.preset', 'channels.chan11.gate', 'channels.chan12', 'channels.chan12.chname', 'channels.chan12.preset', 'channels.chan12.gate', 'channels.chan13', 'channels.chan13.chname', 'channels.chan13.preset', 'channels.chan13.gate', 'channels.chan14', 'channels.chan14.chname', 'channels.chan14.preset', 'channels.chan14.gate', 'channels.chan15', 'channels.chan15.chname', 'channels.chan15.preset', 'channels.chan15.gate', 'channels.chan16', 'channels.chan16.chname', 'channels.chan16.preset', 'channels.chan16.gate', 'channels.chan17', 'channels.chan17.chname', 'channels.chan17.preset', 'channels.chan17.gate', 'channels.chan18', 'channels.chan18.chname', 'channels.chan18.preset', 'channels.chan18.gate', 'channels.chan19', 'channels.chan19.chname', 'channels.chan19.preset', 'channels.chan19.gate', 'channels.chan20', 'channels.chan20.chname', 'channels.chan20.preset', 'channels.chan20.gate', 'channels.chan21', 'channels.chan21.chname', 'channels.chan21.preset', 'channels.chan21.gate', 'channels.chan22', 'channels.chan22.chname', 'channels.chan22.preset', 'channels.chan22.gate', 'channels.chan23', 'channels.chan23.chname', 'channels.chan23.preset', 'channels.chan23.gate', 'channels.chan24', 'channels.chan24.chname', 'channels.chan24.preset', 'channels.chan24.gate', 'channels.chan25', 'channels.chan25.chname', 'channels.chan25.preset', 'channels.chan25.gate', 'channels.chan26', 'channels.chan26.chname', 'channels.chan26.preset', 'channels.chan26.gate', 'channels.chan27', 'channels.chan27.chname', 'channels.chan27.preset', 'channels.chan27.gate', 'channels.chan28', 'channels.chan28.chname', 'channels.chan28.preset', 'channels.chan28.gate', 'channels.chan29', 'channels.chan29.chname', 'channels.chan29.preset', 'channels.chan29.gate', 'channels.chan30', 'channels.chan30.chname', 'channels.chan30.preset', 'channels.chan30.gate', 'channels.chan31', 'channels.chan31.chname', 'channels.chan31.preset', 'channels.chan31.gate', 'channels.chan32', 'channels.chan32.chname', 'channels.chan32.preset', 'channels.chan32.gate', 'count_mode', 'delay', 'auto_count_delay', 'freq', 'preset_time', 'auto_count_time', 'egu'])"]
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.1, 0.1, 3, False]
#   per_step        : <function optimize_energy_per_step at 0x7f3e38557158>
# plan_name       : rel_grid_scan
# plan_pattern    : outer_product
# plan_pattern_args:
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.1, 0.1, 3, False]
# plan_pattern_mod: bluesky.plan_patterns
# plan_type       : generator
# proposal_id     : None
# sample_name     : test
# scan_id         : 43
# shape           : [1, 3]
# snaking         : [False, False]
# time            : 1540763459.6808147
# uid             : 8ee33a6f-0a74-43fa-8d1d-99e94e868811
#
# Run Start
# =========
# BLUESKY_VERSION : 1.3.3
# EPICS_AR_PORT   : 7002
# EPICS_CA_MAX_ARR: 16777216
# EPICS_EXTENSIONS: /APSshare/epics/extensions
# EPICS_HOST_ARCH : linux-x86_64
# OPHYD_VERSION   : 1.2.0
# beamline_id     : 3-ID
# detectors       : ['mca', 'scaler']
# extents         : [[0, 0], [-0.1, 0.1]]
# hints           :
#   gridding        : rectilinear
#   dimensions      : [[['neat_stage_y'], 'primary'], [['neat_stage_x'], 'primary']]
# login_id        : s3blue@ni.xray.aps.anl.gov
# motors          : ['neat_stage_y', 'neat_stage_x']
# num_intervals   : 2
# num_points      : 3
# pid             : 28587
# plan_args       :
#   detectors       : ["EpicsMCA(prefix='3ida:mca1', name='mca', read_attrs=['preset_real_time', 'elapsed_real_time', 'spectrum'], configuration_attrs=['preset_real_time'])", "ScalerCH(prefix='3idb:scaler1', name='scaler', read_attrs=['channels', 'channels.chan01', 'channels.chan01.s', 'channels.chan02', 'channels.chan02.s', 'channels.chan03', 'channels.chan03.s', 'channels.chan04', 'channels.chan04.s', 'channels.chan05', 'channels.chan05.s', 'channels.chan06', 'channels.chan06.s', 'channels.chan07', 'channels.chan07.s', 'channels.chan08', 'channels.chan08.s', 'time'], configuration_attrs=['channels', 'channels.chan01', 'channels.chan01.chname', 'channels.chan01.preset', 'channels.chan01.gate', 'channels.chan02', 'channels.chan02.chname', 'channels.chan02.preset', 'channels.chan02.gate', 'channels.chan03', 'channels.chan03.chname', 'channels.chan03.preset', 'channels.chan03.gate', 'channels.chan04', 'channels.chan04.chname', 'channels.chan04.preset', 'channels.chan04.gate', 'channels.chan05', 'channels.chan05.chname', 'channels.chan05.preset', 'channels.chan05.gate', 'channels.chan06', 'channels.chan06.chname', 'channels.chan06.preset', 'channels.chan06.gate', 'channels.chan07', 'channels.chan07.chname', 'channels.chan07.preset', 'channels.chan07.gate', 'channels.chan08', 'channels.chan08.chname', 'channels.chan08.preset', 'channels.chan08.gate', 'channels.chan09', 'channels.chan09.chname', 'channels.chan09.preset', 'channels.chan09.gate', 'channels.chan10', 'channels.chan10.chname', 'channels.chan10.preset', 'channels.chan10.gate', 'channels.chan11', 'channels.chan11.chname', 'channels.chan11.preset', 'channels.chan11.gate', 'channels.chan12', 'channels.chan12.chname', 'channels.chan12.preset', 'channels.chan12.gate', 'channels.chan13', 'channels.chan13.chname', 'channels.chan13.preset', 'channels.chan13.gate', 'channels.chan14', 'channels.chan14.chname', 'channels.chan14.preset', 'channels.chan14.gate', 'channels.chan15', 'channels.chan15.chname', 'channels.chan15.preset', 'channels.chan15.gate', 'channels.chan16', 'channels.chan16.chname', 'channels.chan16.preset', 'channels.chan16.gate', 'channels.chan17', 'channels.chan17.chname', 'channels.chan17.preset', 'channels.chan17.gate', 'channels.chan18', 'channels.chan18.chname', 'channels.chan18.preset', 'channels.chan18.gate', 'channels.chan19', 'channels.chan19.chname', 'channels.chan19.preset', 'channels.chan19.gate', 'channels.chan20', 'channels.chan20.chname', 'channels.chan20.preset', 'channels.chan20.gate', 'channels.chan21', 'channels.chan21.chname', 'channels.chan21.preset', 'channels.chan21.gate', 'channels.chan22', 'channels.chan22.chname', 'channels.chan22.preset', 'channels.chan22.gate', 'channels.chan23', 'channels.chan23.chname', 'channels.chan23.preset', 'channels.chan23.gate', 'channels.chan24', 'channels.chan24.chname', 'channels.chan24.preset', 'channels.chan24.gate', 'channels.chan25', 'channels.chan25.chname', 'channels.chan25.preset', 'channels.chan25.gate', 'channels.chan26', 'channels.chan26.chname', 'channels.chan26.preset', 'channels.chan26.gate', 'channels.chan27', 'channels.chan27.chname', 'channels.chan27.preset', 'channels.chan27.gate', 'channels.chan28', 'channels.chan28.chname', 'channels.chan28.preset', 'channels.chan28.gate', 'channels.chan29', 'channels.chan29.chname', 'channels.chan29.preset', 'channels.chan29.gate', 'channels.chan30', 'channels.chan30.chname', 'channels.chan30.preset', 'channels.chan30.gate', 'channels.chan31', 'channels.chan31.chname', 'channels.chan31.preset', 'channels.chan31.gate', 'channels.chan32', 'channels.chan32.chname', 'channels.chan32.preset', 'channels.chan32.gate', 'count_mode', 'delay', 'auto_count_delay', 'freq', 'preset_time', 'auto_count_time', 'egu'])"]
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.1, 0.1, 3, False]
#   per_step        : <function optimize_energy_per_step at 0x7f3e38557158>
# plan_name       : rel_grid_scan
# plan_pattern    : outer_product
# plan_pattern_args:
#   args            : ["EpicsMotor(prefix='3idb:m38', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idb:m37', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -0.1, 0.1, 3, False]
# plan_pattern_mod: bluesky.plan_patterns
# plan_type       : generator
# proposal_id     : None
# sample_name     : test
# scan_id         : 42
# shape           : [1, 3]
# snaking         : [False, False]
# time            : 1540763280.9453845
# uid             : ed1ee892-61a3-4b8a-bb3d-4b108465a9e0
#
# Run Start
# =========
# BLUESKY_VERSION : 1.3.3
# EPICS_AR_PORT   : 7002
# EPICS_CA_MAX_ARR: 16777216
# EPICS_EXTENSIONS: /APSshare/epics/extensions
# EPICS_HOST_ARCH : linux-x86_64
# OPHYD_VERSION   : 1.2.0
# beamline_id     : 3-ID
# detectors       : ['mca', 'scaler']
# extents         : [[0, 0], [-0.1, 0.1]]
# hints           :
#   gridding        : rectilinear
#   dimensions      : [[['neat_stage_y'], 'primary'], [['neat_stage_x'], 'primary']]
# login_id        : s3blue@ni.xray.aps.anl.gov
# motors          : ['neat_stage_y', 'neat_stage_x']
# num_intervals   : 2
# num_points      : 3
# pid             : 14521
# plan_args       :
# ...
#   args            : ["EpicsMotor(prefix='3idd:m2', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idd:m1', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -2, 2, 3, False]
#   per_step        : <function optimize_energy_per_step at 0x7f0f35e9dae8>
# plan_name       : rel_grid_scan
# plan_pattern    : outer_product
# plan_pattern_args:
#   args            : ["EpicsMotor(prefix='3idd:m2', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idd:m1', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -2, 2, 3, False]
# plan_pattern_mod: bluesky.plan_patterns
# plan_type       : generator
# proposal_id     : None
# sample_name     : sample-test-2
# scan_id         : 18
# shape           : [1, 3]
# snaking         : [False, False]
# time            : 1540428584.5447736
# uid             : 680dc04e-f271-4cec-b566-3439b760c067
#
# Run Start
# =========
# BLUESKY_VERSION : 1.3.3
# EPICS_AR_PORT   : 7002
# EPICS_CA_MAX_ARR: 16777216
# EPICS_EXTENSIONS: /APSshare/epics/extensions
# EPICS_HOST_ARCH : linux-x86_64
# OPHYD_VERSION   : 1.2.0
# beamline_id     : 3-ID
# detectors       : ['mca', 'scaler']
# extents         : [[0, 0], [-2, 2]]
# hints           :
#   gridding        : rectilinear
#   dimensions      : [[['neat_stage_y'], 'primary'], [['neat_stage_x'], 'primary']]
# login_id        : s3blue@fe.xray.aps.anl.gov
# motors          : ['neat_stage_y', 'neat_stage_x']
# num_intervals   : 2
# num_points      : 3
# pid             : 23674
# plan_args       :
#   detectors       : ["EpicsMCA(prefix='3idd:mca1', name='mca', read_attrs=['preset_real_time', 'elapsed_real_time', 'spectrum'], configuration_attrs=['preset_real_time'])", "ScalerCH(prefix='3idd:scaler1', name='scaler', read_attrs=['channels', 'channels.chan01', 'channels.chan01.s', 'channels.chan02', 'channels.chan02.s', 'channels.chan03', 'channels.chan03.s', 'channels.chan04', 'channels.chan04.s', 'channels.chan05', 'channels.chan05.s', 'channels.chan06', 'channels.chan06.s', 'channels.chan07', 'channels.chan07.s', 'channels.chan08', 'channels.chan08.s', 'time'], configuration_attrs=['channels', 'channels.chan01', 'channels.chan01.chname', 'channels.chan01.preset', 'channels.chan01.gate', 'channels.chan02', 'channels.chan02.chname', 'channels.chan02.preset', 'channels.chan02.gate', 'channels.chan03', 'channels.chan03.chname', 'channels.chan03.preset', 'channels.chan03.gate', 'channels.chan04', 'channels.chan04.chname', 'channels.chan04.preset', 'channels.chan04.gate', 'channels.chan05', 'channels.chan05.chname', 'channels.chan05.preset', 'channels.chan05.gate', 'channels.chan06', 'channels.chan06.chname', 'channels.chan06.preset', 'channels.chan06.gate', 'channels.chan07', 'channels.chan07.chname', 'channels.chan07.preset', 'channels.chan07.gate', 'channels.chan08', 'channels.chan08.chname', 'channels.chan08.preset', 'channels.chan08.gate', 'channels.chan09', 'channels.chan09.chname', 'channels.chan09.preset', 'channels.chan09.gate', 'channels.chan10', 'channels.chan10.chname', 'channels.chan10.preset', 'channels.chan10.gate', 'channels.chan11', 'channels.chan11.chname', 'channels.chan11.preset', 'channels.chan11.gate', 'channels.chan12', 'channels.chan12.chname', 'channels.chan12.preset', 'channels.chan12.gate', 'channels.chan13', 'channels.chan13.chname', 'channels.chan13.preset', 'channels.chan13.gate', 'channels.chan14', 'channels.chan14.chname', 'channels.chan14.preset', 'channels.chan14.gate', 'channels.chan15', 'channels.chan15.chname', 'channels.chan15.preset', 'channels.chan15.gate', 'channels.chan16', 'channels.chan16.chname', 'channels.chan16.preset', 'channels.chan16.gate', 'channels.chan17', 'channels.chan17.chname', 'channels.chan17.preset', 'channels.chan17.gate', 'channels.chan18', 'channels.chan18.chname', 'channels.chan18.preset', 'channels.chan18.gate', 'channels.chan19', 'channels.chan19.chname', 'channels.chan19.preset', 'channels.chan19.gate', 'channels.chan20', 'channels.chan20.chname', 'channels.chan20.preset', 'channels.chan20.gate', 'channels.chan21', 'channels.chan21.chname', 'channels.chan21.preset', 'channels.chan21.gate', 'channels.chan22', 'channels.chan22.chname', 'channels.chan22.preset', 'channels.chan22.gate', 'channels.chan23', 'channels.chan23.chname', 'channels.chan23.preset', 'channels.chan23.gate', 'channels.chan24', 'channels.chan24.chname', 'channels.chan24.preset', 'channels.chan24.gate', 'channels.chan25', 'channels.chan25.chname', 'channels.chan25.preset', 'channels.chan25.gate', 'channels.chan26', 'channels.chan26.chname', 'channels.chan26.preset', 'channels.chan26.gate', 'channels.chan27', 'channels.chan27.chname', 'channels.chan27.preset', 'channels.chan27.gate', 'channels.chan28', 'channels.chan28.chname', 'channels.chan28.preset', 'channels.chan28.gate', 'channels.chan29', 'channels.chan29.chname', 'channels.chan29.preset', 'channels.chan29.gate', 'channels.chan30', 'channels.chan30.chname', 'channels.chan30.preset', 'channels.chan30.gate', 'channels.chan31', 'channels.chan31.chname', 'channels.chan31.preset', 'channels.chan31.gate', 'channels.chan32', 'channels.chan32.chname', 'channels.chan32.preset', 'channels.chan32.gate', 'count_mode', 'delay', 'auto_count_delay', 'freq', 'preset_time', 'auto_count_time', 'egu'])"]
#   args            : ["EpicsMotor(prefix='3idd:m2', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idd:m1', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -2, 2, 3, False]
#   per_step        : <function optimize_energy_per_step at 0x7f5d61702a60>
# plan_name       : rel_grid_scan
# plan_pattern    : outer_product
# plan_pattern_args:
#   args            : ["EpicsMotor(prefix='3idd:m2', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", 0, 0, 1, "EpicsMotor(prefix='3idd:m1', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -2, 2, 3, False]
# plan_pattern_mod: bluesky.plan_patterns
# plan_type       : generator
# proposal_id     : None
# sample_name     : sample-test-2
# scan_id         : 17
# shape           : [1, 3]
# snaking         : [False, False]
# time            : 1540427828.7970352
# uid             : 85c83a7f-b4da-4c46-a226-6e54c41a93be
#
# Run Start
# =========
# BLUESKY_VERSION : 1.3.3
# EPICS_AR_PORT   : 7002
# EPICS_CA_MAX_ARR: 16777216
# EPICS_EXTENSIONS: /APSshare/epics/extensions
# EPICS_HOST_ARCH : linux-x86_64
# OPHYD_VERSION   : 1.2.0
# beamline_id     : 3-ID
# detectors       : ['mca', 'scaler']
# extents         : [[-1, 1], [-2, 2]]
# hints           :
#   gridding        : rectilinear
#   dimensions      : [[['neat_stage_y'], 'primary'], [['neat_stage_x'], 'primary']]
# login_id        : s3blue@fe.xray.aps.anl.gov
# motors          : ['neat_stage_y', 'neat_stage_x']
# num_intervals   : 11
# num_points      : 12
# pid             : 10111
# plan_args       :
#   detectors       : ["EpicsMCA(prefix='3idd:mca1', name='mca', read_attrs=['preset_real_time', 'elapsed_real_time', 'spectrum'], configuration_attrs=['preset_real_time'])", "ScalerCH(prefix='3idd:scaler1', name='scaler', read_attrs=['channels', 'channels.chan01', 'channels.chan01.s', 'channels.chan02', 'channels.chan02.s', 'channels.chan03', 'channels.chan03.s', 'channels.chan04', 'channels.chan04.s', 'channels.chan05', 'channels.chan05.s', 'channels.chan06', 'channels.chan06.s', 'channels.chan07', 'channels.chan07.s', 'channels.chan08', 'channels.chan08.s', 'time'], configuration_attrs=['channels', 'channels.chan01', 'channels.chan01.chname', 'channels.chan01.preset', 'channels.chan01.gate', 'channels.chan02', 'channels.chan02.chname', 'channels.chan02.preset', 'channels.chan02.gate', 'channels.chan03', 'channels.chan03.chname', 'channels.chan03.preset', 'channels.chan03.gate', 'channels.chan04', 'channels.chan04.chname', 'channels.chan04.preset', 'channels.chan04.gate', 'channels.chan05', 'channels.chan05.chname', 'channels.chan05.preset', 'channels.chan05.gate', 'channels.chan06', 'channels.chan06.chname', 'channels.chan06.preset', 'channels.chan06.gate', 'channels.chan07', 'channels.chan07.chname', 'channels.chan07.preset', 'channels.chan07.gate', 'channels.chan08', 'channels.chan08.chname', 'channels.chan08.preset', 'channels.chan08.gate', 'channels.chan09', 'channels.chan09.chname', 'channels.chan09.preset', 'channels.chan09.gate', 'channels.chan10', 'channels.chan10.chname', 'channels.chan10.preset', 'channels.chan10.gate', 'channels.chan11', 'channels.chan11.chname', 'channels.chan11.preset', 'channels.chan11.gate', 'channels.chan12', 'channels.chan12.chname', 'channels.chan12.preset', 'channels.chan12.gate', 'channels.chan13', 'channels.chan13.chname', 'channels.chan13.preset', 'channels.chan13.gate', 'channels.chan14', 'channels.chan14.chname', 'channels.chan14.preset', 'channels.chan14.gate', 'channels.chan15', 'channels.chan15.chname', 'channels.chan15.preset', 'channels.chan15.gate', 'channels.chan16', 'channels.chan16.chname', 'channels.chan16.preset', 'channels.chan16.gate', 'channels.chan17', 'channels.chan17.chname', 'channels.chan17.preset', 'channels.chan17.gate', 'channels.chan18', 'channels.chan18.chname', 'channels.chan18.preset', 'channels.chan18.gate', 'channels.chan19', 'channels.chan19.chname', 'channels.chan19.preset', 'channels.chan19.gate', 'channels.chan20', 'channels.chan20.chname', 'channels.chan20.preset', 'channels.chan20.gate', 'channels.chan21', 'channels.chan21.chname', 'channels.chan21.preset', 'channels.chan21.gate', 'channels.chan22', 'channels.chan22.chname', 'channels.chan22.preset', 'channels.chan22.gate', 'channels.chan23', 'channels.chan23.chname', 'channels.chan23.preset', 'channels.chan23.gate', 'channels.chan24', 'channels.chan24.chname', 'channels.chan24.preset', 'channels.chan24.gate', 'channels.chan25', 'channels.chan25.chname', 'channels.chan25.preset', 'channels.chan25.gate', 'channels.chan26', 'channels.chan26.chname', 'channels.chan26.preset', 'channels.chan26.gate', 'channels.chan27', 'channels.chan27.chname', 'channels.chan27.preset', 'channels.chan27.gate', 'channels.chan28', 'channels.chan28.chname', 'channels.chan28.preset', 'channels.chan28.gate', 'channels.chan29', 'channels.chan29.chname', 'channels.chan29.preset', 'channels.chan29.gate', 'channels.chan30', 'channels.chan30.chname', 'channels.chan30.preset', 'channels.chan30.gate', 'channels.chan31', 'channels.chan31.chname', 'channels.chan31.preset', 'channels.chan31.gate', 'channels.chan32', 'channels.chan32.chname', 'channels.chan32.preset', 'channels.chan32.gate', 'count_mode', 'delay', 'auto_count_delay', 'freq', 'preset_time', 'auto_count_time', 'egu'])"]
#   args            : ["EpicsMotor(prefix='3idd:m2', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -1, 1, 4, "EpicsMotor(prefix='3idd:m1', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -2, 2, 3, False]
#   per_step        : <function optimize_energy_per_step at 0x7f69b93fea60>
# plan_name       : rel_grid_scan
# plan_pattern    : outer_product
# plan_pattern_args:
#   args            : ["EpicsMotor(prefix='3idd:m2', name='neat_stage_y', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -1, 1, 4, "EpicsMotor(prefix='3idd:m1', name='neat_stage_x', parent='neat_stage', settle_time=0.0, timeout=None, read_attrs=['user_readback', 'user_setpoint'], configuration_attrs=['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu'])", -2, 2, 3, False]
# plan_pattern_mod: bluesky.plan_patterns
# plan_type       : generator
# proposal_id     : None
# sample_name     : sample-test
# scan_id         : 16
# shape           : [4, 3]
# snaking         : [False, False]
# time            : 1540427273.8244326
# uid             : 7ba83cd4-e53d-4596-96d4-d1ef03cb3528

# %% [markdown]
# All those scans have the key `beamline_id="3-ID"` so get all the scan (headers) that match that key.  Print the results in a nicer table.

# %%
tbl = pyRestTable.Table()
tbl.labels = "date/time # uid plan_name".split()
headers = otz_db(beamline_id='3-ID')
for h in headers:
    t_float = h.start["time"]
    dt = datetime.datetime.fromtimestamp(t_float)
    row = [dt, h.start["scan_id"], h.start["uid"], h.start["plan_name"]]
    tbl.addRow(row)
print(tbl)
# Out:
# ========================== == ==================================== =============
# date/time                  #  uid                                  plan_name
# ========================== == ==================================== =============
# 2018-10-29 03:45:24.167806 48 6ea22d45-7b57-4936-b007-a6129a04a28c rel_grid_scan
# 2018-10-28 18:56:00.852009 47 b7f9a22f-bff3-4fca-8223-3fe3c13cf04a rel_grid_scan
# 2018-10-28 18:44:26.594428 46 ab52f840-7919-4925-8c62-790a0bf629ef rel_grid_scan
# 2018-10-28 16:59:11.531815 45 8b318daa-c3ee-46d3-9d42-15c51f2e7598 rel_grid_scan
# 2018-10-28 16:53:30.997551 44 a4b7fd59-7875-489a-8a5f-1cc44f311760 rel_grid_scan
# 2018-10-28 16:50:59.680815 43 8ee33a6f-0a74-43fa-8d1d-99e94e868811 rel_grid_scan
# 2018-10-28 16:48:00.945385 42 ed1ee892-61a3-4b8a-bb3d-4b108465a9e0 rel_grid_scan
# 2018-10-28 16:37:31.415016 41 7769bca7-bccd-42de-8459-9676d7dcde86 rel_grid_scan
# 2018-10-28 16:31:16.187840 40 57e0b82d-939b-4547-8eff-9eaad0401712 rel_grid_scan
# 2018-10-28 16:28:51.544602 39 d3308305-a0ff-4f1b-8340-7b16df5b7053 rel_grid_scan
# 2018-10-28 16:05:57.196543 38 733c4521-5ab4-4857-854a-75a8ca249fe6 rel_grid_scan
# 2018-10-28 15:45:40.536218 37 396c81f0-6110-4bde-b549-ec48812b40a8 rel_grid_scan
# 2018-10-27 23:52:53.588539 36 01926905-2ff0-40a4-b253-67deae9d7c7b rel_grid_scan
# 2018-10-27 18:27:05.770915 35 4700d36a-dd84-4275-834b-7b4ea12ffe2b rel_grid_scan
# 2018-10-27 18:09:19.366143 34 4ae460cd-7966-4405-91da-e82185d84406 rel_grid_scan
# 2018-10-27 17:36:51.579937 33 f6d1aa72-72c7-44a5-8ae9-1ee9b960f654 rel_grid_scan
# 2018-10-27 00:21:22.043864 32 5fd2af11-314e-4057-b33a-e401d999bf58 rel_grid_scan
# 2018-10-26 20:42:02.817106 31 c2fa9ad7-e90a-418c-824d-54f6636bf538 rel_grid_scan
# 2018-10-26 20:37:07.619245 30 4292021b-853d-4a87-9dc2-8003b885a1d6 rel_grid_scan
# 2018-10-26 20:33:48.928205 29 f9ba1761-684f-409f-9293-a8e426db53c5 rel_grid_scan
# 2018-10-26 20:19:31.739925 28 74e4b634-05bc-4bbb-978c-7eef8b123b76 rel_grid_scan
# 2018-10-25 13:04:14.267574 27 2ef46bc6-a8a2-4593-a002-b20a184f9646 rel_grid_scan
# 2018-10-25 08:36:04.851642 26 5772c721-e34d-45c6-9a40-01ecef6a8532 rel_grid_scan
# 2018-10-25 06:35:43.666269 25 a07a8f33-eab7-4c6b-9812-a0786d1813a2 rel_grid_scan
# 2018-10-25 04:56:03.706043 24 69eb0ccc-599d-4cb9-aa35-334096f43074 rel_grid_scan
# 2018-10-25 00:15:59.761783 23 a6f8c355-105a-45cc-ba4b-5084c7ddce99 rel_grid_scan
# 2018-10-24 22:28:28.970919 22 ca7470b5-9eb7-45a7-9f40-5e711736f352 rel_grid_scan
# 2018-10-24 22:24:57.684351 21 29dfcbd5-dca5-4ac4-9bd8-383db442fbf5 rel_grid_scan
# 2018-10-24 20:36:44.014423 20 9052d74a-9784-401a-8b0b-31a1be0e473d rel_grid_scan
# 2018-10-24 20:19:43.563549 19 ea34dc72-b7ea-41d8-b273-d3d197c3fa9a rel_grid_scan
# 2018-10-24 19:49:44.544774 18 680dc04e-f271-4cec-b566-3439b760c067 rel_grid_scan
# 2018-10-24 19:37:08.797035 17 85c83a7f-b4da-4c46-a226-6e54c41a93be rel_grid_scan
# 2018-10-24 19:27:53.824433 16 7ba83cd4-e53d-4596-96d4-d1ef03cb3528 rel_grid_scan
# 2018-10-19 17:47:25.149698 15 f90e5a53-2b18-430c-adb4-fb9042087d1e rel_grid_scan
# 2018-10-19 17:42:03.373177 14 16ef6932-66a2-41c0-afe0-d4e0a50852d7 rel_grid_scan
# 2018-10-19 17:37:52.023404 13 d4cb6d36-7440-4ced-b953-7b029b9e2761 rel_grid_scan
# 2018-10-19 17:36:49.507397 12 517c2fd9-7701-49c8-9445-b357e531cad4 rel_grid_scan
# 2018-10-19 17:36:19.057681 11 3e22dde8-2278-4235-9bae-f55b348b95f3 rel_grid_scan
# 2018-10-19 17:35:05.784959 10 a7c2081f-ffe9-4aa9-974e-107f3036eeb9 rel_grid_scan
# 2018-10-19 17:33:51.071051 9  96de94ce-2271-451f-95a4-84270f3a7fd7 rel_grid_scan
# 2018-10-19 15:36:25.197788 8  eaabd32d-5834-4b8c-8aef-68c2e78aa10d count
# 2018-10-19 15:36:08.681412 7  cb10c20c-acfb-4ad2-99f3-fd9871f2fc29 count
# 2018-10-18 16:21:43.100158 6  4eec1021-774f-4f3f-bf99-e70ee06184dd rel_grid_scan
# 2018-10-18 16:17:50.599962 5  310c2556-54ac-4252-859c-6992fc835df9 rel_grid_scan
# 2018-10-18 16:05:06.579185 4  6b8f5448-3dcf-4819-8a91-6c68c1c77a13 rel_grid_scan
# 2018-10-18 15:49:49.691615 3  933159fe-e7a9-4894-9867-cb34062d1d28 rel_grid_scan
# 2018-10-18 15:20:00.629276 2  118f8c91-205d-43d1-9862-d1dca09c5af8 rel_grid_scan
# 2018-10-18 15:10:38.303804 1  0b481920-1617-49f2-a2a3-05dcccb69dc3 grid_scan
# ========================== == ==================================== =============

# %% [markdown]
# -----------

# %% [markdown]
# ## build a local sqlite database for testing

# %%
test_dir = "/tmp/bluesky"
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

test_config = {
    "description": "lightweight personal database",
    "metadatastore": {
        "module": "databroker.headersource.sqlite",
        "class": "MDS",
        "config": {
            "directory": test_dir,
            "timezone": "US/Central"
        }
    },
    "assets": {
        "module": "databroker.assets.sqlite",
        "class": "Registry",
        "config": {
            "dbpath": test_dir + "/database.sql"
        }
    }
}
test_db = Broker.from_config(test_config)

# %% [markdown]
# ## Export (test)
# export from otz_db to test_db

# %%
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
    os.makedirs(test_dir)

otz_db.export(headers, test_db)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-6-d69474875df0> in <module>()
#       3     os.makedirs(test_dir)
#       4
# ----> 5 otz_db.export(headers, test_db)
#
# ~/Apps/BlueSky/lib/python3.6/site-packages/databroker/_core.py in export(self, headers, db, new_root, copy_kwargs)
#    1859             events = self.get_events(header)
#    1860             for descriptor in header['descriptors']:
# -> 1861                 db.mds.insert_descriptor(**_sanitize(descriptor))
#    1862                 for event in events:
#    1863                     db.mds.insert_event(**_sanitize(event))
#
# ~/Apps/BlueSky/lib/python3.6/site-packages/databroker/headersource/base.py in insert_descriptor(self, run_start, data_keys, time, uid, **kwargs)
#     474                                            data_keys=data_keys,
#     475                                            time=time, uid=uid,
# --> 476                                            **kwargs)
#     477
#     478     def insert_event(self, descriptor, time, seq_num, data, timestamps, uid,
#
# ~/Apps/BlueSky/lib/python3.6/site-packages/databroker/headersource/core.py in insert_descriptor(descriptor_col, descriptor_cache, run_start, data_keys, time, uid, **kwargs)
#     642     apply_to_dict_recursively(descriptor, sanitize_np)
#     643     # TODO validation
# --> 644     col.insert_one(descriptor)
#     645
#     646     descriptor = _cache_descriptor(descriptor, descriptor_cache)
#
# ~/Apps/BlueSky/lib/python3.6/site-packages/databroker/headersource/sqlite.py in insert_one(self, doc)
#      66
#      67     def insert_one(self, doc):
# ---> 68         self._event_col.new_descriptor(doc)
#      69         super(DescriptorCollection, self).insert_one(doc)
#      70
#
# ~/Apps/BlueSky/lib/python3.6/site-packages/databroker/headersource/sqlite.py in new_descriptor(self, doc)
#     140         excp = ret.get('exception')
#     141         if excp is not None:
# --> 142             raise excp
#     143
#     144     def find(self, query, sort=None):
#
# ~/Apps/BlueSky/lib/python3.6/site-packages/databroker/headersource/sqlite.py in __process_request_queue(self)
#     217                     self._insert_events(payload)
#     218                 elif name == 'descriptor':
# --> 219                     self._insert_descriptor(payload)
#     220                 elif name == 'start':
#     221                     self._insert_start(payload)
#
# ~/Apps/BlueSky/lib/python3.6/site-packages/databroker/headersource/sqlite.py in _insert_descriptor(self, doc)
#     264         with cursor(self._runstarts[run_start_uid]) as c:
#     265             c.execute(CREATE_TABLE % table_name
# --> 266                       + '(' + ','.join(columns) + ')')
#     267         self._descriptors[uid] = run_start_uid
#     268
#
# OperationalError: duplicate column name: data_NFS

# %%
h = list(headers)[-1]
h.descriptors
# Out:
# [{'run_start': '0b481920-1617-49f2-a2a3-05dcccb69dc3',
#   'data_keys': {'Time': {'source': 'PV:3idd:scaler1.S1',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 0,
#     'units': '',
#     'lower_ctrl_limit': 0.0,
#     'upper_ctrl_limit': 0.0,
#     'object_name': 'scaler'},
#    'IC0_D': {'source': 'PV:3idd:scaler1.S2',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 0,
#     'units': '',
#     'lower_ctrl_limit': 0.0,
#     'upper_ctrl_limit': 0.0,
#     'object_name': 'scaler'},
#    'PIN': {'source': 'PV:3idd:scaler1.S3',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 0,
#     'units': '',
#     'lower_ctrl_limit': 0.0,
#     'upper_ctrl_limit': 0.0,
#     'object_name': 'scaler'},
#    'NaI': {'source': 'PV:3idd:scaler1.S4',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 0,
#     'units': '',
#     'lower_ctrl_limit': 0.0,
#     'upper_ctrl_limit': 0.0,
#     'object_name': 'scaler'},
#    'Fwd prompt': {'source': 'PV:3idd:scaler1.S5',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 0,
#     'units': '',
#     'lower_ctrl_limit': 0.0,
#     'upper_ctrl_limit': 0.0,
#     'object_name': 'scaler'},
#    'NFS delayed': {'source': 'PV:3idd:scaler1.S6',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 0,
#     'units': '',
#     'lower_ctrl_limit': 0.0,
#     'upper_ctrl_limit': 0.0,
#     'object_name': 'scaler'},
#    'NRIXS prompt': {'source': 'PV:3idd:scaler1.S7',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 0,
#     'units': '',
#     'lower_ctrl_limit': 0.0,
#     'upper_ctrl_limit': 0.0,
#     'object_name': 'scaler'},
#    'NRIXS Delayed': {'source': 'PV:3idd:scaler1.S8',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 0,
#     'units': '',
#     'lower_ctrl_limit': 0.0,
#     'upper_ctrl_limit': 0.0,
#     'object_name': 'scaler'},
#    'scaler_time': {'source': 'PV:3idd:scaler1.T',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 3,
#     'units': '',
#     'lower_ctrl_limit': 0.0,
#     'upper_ctrl_limit': 0.0,
#     'object_name': 'scaler'},
#    'neat_stage_x': {'source': 'PV:3idd:m1.RBV',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 3,
#     'units': 'mm',
#     'lower_ctrl_limit': -42.0,
#     'upper_ctrl_limit': 58.0,
#     'object_name': 'neat_stage_x'},
#    'neat_stage_x_user_setpoint': {'source': 'PV:3idd:m1.VAL',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 3,
#     'units': 'mm',
#     'lower_ctrl_limit': -42.0,
#     'upper_ctrl_limit': 58.0,
#     'object_name': 'neat_stage_x'},
#    'mca_preset_real_time': {'source': 'PV:3idd:mca1.PRTM',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 2,
#     'units': '',
#     'lower_ctrl_limit': -1e+300,
#     'upper_ctrl_limit': 1e+300,
#     'object_name': 'mca'},
#    'mca_elapsed_real_time': {'source': 'PV:3idd:mca1.ERTM',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 2,
#     'units': '',
#     'lower_ctrl_limit': -1e+300,
#     'upper_ctrl_limit': 1e+300,
#     'object_name': 'mca'},
#    'mca_spectrum': {'source': 'PV:3idd:mca1.VAL',
#     'dtype': 'array',
#     'shape': [4096],
#     'units': '',
#     'lower_ctrl_limit': 0,
#     'upper_ctrl_limit': 0,
#     'object_name': 'mca'},
#    'neat_stage_y': {'source': 'PV:3idd:m2.RBV',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 3,
#     'units': 'mm',
#     'lower_ctrl_limit': -80.0,
#     'upper_ctrl_limit': 76.0,
#     'object_name': 'neat_stage_y'},
#    'neat_stage_y_user_setpoint': {'source': 'PV:3idd:m2.VAL',
#     'dtype': 'number',
#     'shape': [],
#     'precision': 3,
#     'units': 'mm',
#     'lower_ctrl_limit': -80.0,
#     'upper_ctrl_limit': 76.0,
#     'object_name': 'neat_stage_y'}},
#   'time': 1539893446.7352624,
#   'uid': '56aa28b1-621b-47ba-8d19-0ae05b30088e',
#   'configuration': {'scaler': {'data': {'scaler_channels_chan01_chname': 'Time',
#      'scaler_channels_chan01_preset': 2500000.0,
#      'scaler_channels_chan01_gate': 'Y',
#      'scaler_channels_chan02_chname': 'IC0_D',
#      'scaler_channels_chan02_preset': 150000.0,
#      'scaler_channels_chan02_gate': 'N',
#      'scaler_channels_chan03_chname': 'PIN',
#      'scaler_channels_chan03_preset': 1000.0,
#      'scaler_channels_chan03_gate': 'N',
#      'scaler_channels_chan04_chname': 'NaI',
#      'scaler_channels_chan04_preset': 1000.0,
#      'scaler_channels_chan04_gate': 'N',
#      'scaler_channels_chan05_chname': 'Fwd prompt',
#      'scaler_channels_chan05_preset': 1000.0,
#      'scaler_channels_chan05_gate': 'N',
#      'scaler_channels_chan06_chname': 'NFS delayed',
#      'scaler_channels_chan06_preset': 1000.0,
#      'scaler_channels_chan06_gate': 'N',
#      'scaler_channels_chan07_chname': 'NRIXS prompt',
#      'scaler_channels_chan07_preset': 1000.0,
#      'scaler_channels_chan07_gate': 'N',
#      'scaler_channels_chan08_chname': 'NRIXS Delayed',
#      'scaler_channels_chan08_preset': 1000.0,
#      'scaler_channels_chan08_gate': 'N',
#      'scaler_channels_chan09_chname': '',
#      'scaler_channels_chan09_preset': 0.0,
#      'scaler_channels_chan09_gate': 'N',
#      'scaler_channels_chan10_chname': '',
#      'scaler_channels_chan10_preset': 0.0,
#      'scaler_channels_chan10_gate': 'N',
#      'scaler_channels_chan11_chname': '',
#      'scaler_channels_chan11_preset': 0.0,
#      'scaler_channels_chan11_gate': 'N',
#      'scaler_channels_chan12_chname': '',
#      'scaler_channels_chan12_preset': 0.0,
#      'scaler_channels_chan12_gate': 'N',
#      'scaler_channels_chan13_chname': '',
#      'scaler_channels_chan13_preset': 0.0,
#      'scaler_channels_chan13_gate': 'N',
#      'scaler_channels_chan14_chname': '',
#      'scaler_channels_chan14_preset': 0.0,
#      'scaler_channels_chan14_gate': 'N',
#      'scaler_channels_chan15_chname': '',
#      'scaler_channels_chan15_preset': 0.0,
#      'scaler_channels_chan15_gate': 'N',
#      'scaler_channels_chan16_chname': '',
#      'scaler_channels_chan16_preset': 0.0,
#      'scaler_channels_chan16_gate': 'N',
#      'scaler_channels_chan17_chname': '',
#      'scaler_channels_chan17_preset': 0.0,
#      'scaler_channels_chan17_gate': 'N',
#      'scaler_channels_chan18_chname': '',
#      'scaler_channels_chan18_preset': 0.0,
#      'scaler_channels_chan18_gate': 'N',
#      'scaler_channels_chan19_chname': '',
#      'scaler_channels_chan19_preset': 0.0,
#      'scaler_channels_chan19_gate': 'N',
#      'scaler_channels_chan20_chname': '',
#      'scaler_channels_chan20_preset': 0.0,
#      'scaler_channels_chan20_gate': 'N',
#      'scaler_channels_chan21_chname': '',
#      'scaler_channels_chan21_preset': 0.0,
#      'scaler_channels_chan21_gate': 'N',
#      'scaler_channels_chan22_chname': '',
#      'scaler_channels_chan22_preset': 0.0,
#      'scaler_channels_chan22_gate': 'N',
#      'scaler_channels_chan23_chname': '',
#      'scaler_channels_chan23_preset': 0.0,
#      'scaler_channels_chan23_gate': 'N',
#      'scaler_channels_chan24_chname': '',
#      'scaler_channels_chan24_preset': 0.0,
#      'scaler_channels_chan24_gate': 'N',
#      'scaler_channels_chan25_chname': '',
#      'scaler_channels_chan25_preset': 0.0,
#      'scaler_channels_chan25_gate': 'N',
#      'scaler_channels_chan26_chname': '',
#      'scaler_channels_chan26_preset': 0.0,
#      'scaler_channels_chan26_gate': 'N',
#      'scaler_channels_chan27_chname': '',
#      'scaler_channels_chan27_preset': 0.0,
#      'scaler_channels_chan27_gate': 'N',
#      'scaler_channels_chan28_chname': '',
#      'scaler_channels_chan28_preset': 0.0,
#      'scaler_channels_chan28_gate': 'N',
#      'scaler_channels_chan29_chname': '',
#      'scaler_channels_chan29_preset': 0.0,
#      'scaler_channels_chan29_gate': 'N',
#      'scaler_channels_chan30_chname': '',
#      'scaler_channels_chan30_preset': 0.0,
#      'scaler_channels_chan30_gate': 'N',
#      'scaler_channels_chan31_chname': '',
#      'scaler_channels_chan31_preset': 0.0,
#      'scaler_channels_chan31_gate': 'N',
#      'scaler_channels_chan32_chname': '',
#      'scaler_channels_chan32_preset': 0.0,
#      'scaler_channels_chan32_gate': 'N',
#      'scaler_count_mode': 'AutoCount',
#      'scaler_delay': 0.0,
#      'scaler_auto_count_delay': 0.0,
#      'scaler_freq': 10000000.0,
#      'scaler_preset_time': 0.25,
#      'scaler_auto_count_time': 1.0,
#      'scaler_egu': ''},
#     'timestamps': {'scaler_channels_chan01_chname': 1539893445.871373,
#      'scaler_channels_chan01_preset': 1539893445.871373,
#      'scaler_channels_chan01_gate': 1539893445.871373,
#      'scaler_channels_chan02_chname': 1539893445.871373,
#      'scaler_channels_chan02_preset': 1539893445.871373,
#      'scaler_channels_chan02_gate': 1539893445.871373,
#      'scaler_channels_chan03_chname': 1539893445.871373,
#      'scaler_channels_chan03_preset': 1539893445.871373,
#      'scaler_channels_chan03_gate': 1539893445.871373,
#      'scaler_channels_chan04_chname': 1539893445.871373,
#      'scaler_channels_chan04_preset': 1539893445.871373,
#      'scaler_channels_chan04_gate': 1539893445.871373,
#      'scaler_channels_chan05_chname': 1539893445.871373,
#      'scaler_channels_chan05_preset': 1539893445.871373,
#      'scaler_channels_chan05_gate': 1539893445.871373,
#      'scaler_channels_chan06_chname': 1539893445.871373,
#      'scaler_channels_chan06_preset': 1539893445.871373,
#      'scaler_channels_chan06_gate': 1539893445.871373,
#      'scaler_channels_chan07_chname': 1539893445.871373,
#      'scaler_channels_chan07_preset': 1539893445.871373,
#      'scaler_channels_chan07_gate': 1539893445.871373,
#      'scaler_channels_chan08_chname': 1539893445.871373,
#      'scaler_channels_chan08_preset': 1539893445.871373,
#      'scaler_channels_chan08_gate': 1539893445.871373,
#      'scaler_channels_chan09_chname': 1539893445.871373,
#      'scaler_channels_chan09_preset': 1539893445.871373,
#      'scaler_channels_chan09_gate': 1539893445.871373,
#      'scaler_channels_chan10_chname': 1539893445.871373,
#      'scaler_channels_chan10_preset': 1539893445.871373,
#      'scaler_channels_chan10_gate': 1539893445.871373,
#      'scaler_channels_chan11_chname': 1539893445.871373,
#      'scaler_channels_chan11_preset': 1539893445.871373,
#      'scaler_channels_chan11_gate': 1539893445.871373,
#      'scaler_channels_chan12_chname': 1539893445.871373,
#      'scaler_channels_chan12_preset': 1539893445.871373,
#      'scaler_channels_chan12_gate': 1539893445.871373,
#      'scaler_channels_chan13_chname': 1539893445.871373,
#      'scaler_channels_chan13_preset': 1539893445.871373,
#      'scaler_channels_chan13_gate': 1539893445.871373,
#      'scaler_channels_chan14_chname': 1539893445.871373,
#      'scaler_channels_chan14_preset': 1539893445.871373,
#      'scaler_channels_chan14_gate': 1539893445.871373,
#      'scaler_channels_chan15_chname': 1539893445.871373,
#      'scaler_channels_chan15_preset': 1539893445.871373,
#      'scaler_channels_chan15_gate': 1539893445.871373,
#      'scaler_channels_chan16_chname': 1539893445.871373,
#      'scaler_channels_chan16_preset': 1539893445.871373,
#      'scaler_channels_chan16_gate': 1539893445.871373,
#      'scaler_channels_chan17_chname': 1539893445.871373,
#      'scaler_channels_chan17_preset': 1539893445.871373,
#      'scaler_channels_chan17_gate': 1539893445.871373,
#      'scaler_channels_chan18_chname': 1539893445.871373,
#      'scaler_channels_chan18_preset': 1539893445.871373,
#      'scaler_channels_chan18_gate': 1539893445.871373,
#      'scaler_channels_chan19_chname': 1539893445.871373,
#      'scaler_channels_chan19_preset': 1539893445.871373,
#      'scaler_channels_chan19_gate': 1539893445.871373,
#      'scaler_channels_chan20_chname': 1539893445.871373,
#      'scaler_channels_chan20_preset': 1539893445.871373,
#      'scaler_channels_chan20_gate': 1539893445.871373,
#      'scaler_channels_chan21_chname': 1539893445.871373,
#      'scaler_channels_chan21_preset': 1539893445.871373,
#      'scaler_channels_chan21_gate': 1539893445.871373,
#      'scaler_channels_chan22_chname': 1539893445.871373,
#      'scaler_channels_chan22_preset': 1539893445.871373,
#      'scaler_channels_chan22_gate': 1539893445.871373,
#      'scaler_channels_chan23_chname': 1539893445.871373,
#      'scaler_channels_chan23_preset': 1539893445.871373,
#      'scaler_channels_chan23_gate': 1539893445.871373,
#      'scaler_channels_chan24_chname': 1539893445.871373,
#      'scaler_channels_chan24_preset': 1539893445.871373,
#      'scaler_channels_chan24_gate': 1539893445.871373,
#      'scaler_channels_chan25_chname': 1539893445.871373,
#      'scaler_channels_chan25_preset': 1539893445.871373,
#      'scaler_channels_chan25_gate': 1539893445.871373,
#      'scaler_channels_chan26_chname': 1539893445.871373,
#      'scaler_channels_chan26_preset': 1539893445.871373,
#      'scaler_channels_chan26_gate': 1539893445.871373,
#      'scaler_channels_chan27_chname': 1539893445.871373,
#      'scaler_channels_chan27_preset': 1539893445.871373,
#      'scaler_channels_chan27_gate': 1539893445.871373,
#      'scaler_channels_chan28_chname': 1539893445.871373,
#      'scaler_channels_chan28_preset': 1539893445.871373,
#      'scaler_channels_chan28_gate': 1539893445.871373,
#      'scaler_channels_chan29_chname': 1539893445.871373,
#      'scaler_channels_chan29_preset': 1539893445.871373,
#      'scaler_channels_chan29_gate': 1539893445.871373,
#      'scaler_channels_chan30_chname': 1539893445.871373,
#      'scaler_channels_chan30_preset': 1539893445.871373,
#      'scaler_channels_chan30_gate': 1539893445.871373,
#      'scaler_channels_chan31_chname': 1539893445.871373,
#      'scaler_channels_chan31_preset': 1539893445.871373,
#      'scaler_channels_chan31_gate': 1539893445.871373,
#      'scaler_channels_chan32_chname': 1539893445.871373,
#      'scaler_channels_chan32_preset': 1539893445.871373,
#      'scaler_channels_chan32_gate': 1539893445.871373,
#      'scaler_count_mode': 1539893445.871373,
#      'scaler_delay': 1539893445.871373,
#      'scaler_auto_count_delay': 1539893445.871373,
#      'scaler_freq': 1539893445.871373,
#      'scaler_preset_time': 1539893445.871373,
#      'scaler_auto_count_time': 1539893445.871373,
#      'scaler_egu': 1539893445.871373},
#     'data_keys': {'scaler_channels_chan01_chname': {'source': 'PV:3idd:scaler1.NM1',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan01_preset': {'source': 'PV:3idd:scaler1.PR1',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan01_gate': {'source': 'PV:3idd:scaler1.G1',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan02_chname': {'source': 'PV:3idd:scaler1.NM2',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan02_preset': {'source': 'PV:3idd:scaler1.PR2',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan02_gate': {'source': 'PV:3idd:scaler1.G2',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan03_chname': {'source': 'PV:3idd:scaler1.NM3',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan03_preset': {'source': 'PV:3idd:scaler1.PR3',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan03_gate': {'source': 'PV:3idd:scaler1.G3',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan04_chname': {'source': 'PV:3idd:scaler1.NM4',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan04_preset': {'source': 'PV:3idd:scaler1.PR4',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan04_gate': {'source': 'PV:3idd:scaler1.G4',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan05_chname': {'source': 'PV:3idd:scaler1.NM5',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan05_preset': {'source': 'PV:3idd:scaler1.PR5',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan05_gate': {'source': 'PV:3idd:scaler1.G5',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan06_chname': {'source': 'PV:3idd:scaler1.NM6',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan06_preset': {'source': 'PV:3idd:scaler1.PR6',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan06_gate': {'source': 'PV:3idd:scaler1.G6',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan07_chname': {'source': 'PV:3idd:scaler1.NM7',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan07_preset': {'source': 'PV:3idd:scaler1.PR7',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan07_gate': {'source': 'PV:3idd:scaler1.G7',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan08_chname': {'source': 'PV:3idd:scaler1.NM8',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan08_preset': {'source': 'PV:3idd:scaler1.PR8',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan08_gate': {'source': 'PV:3idd:scaler1.G8',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan09_chname': {'source': 'PV:3idd:scaler1.NM9',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan09_preset': {'source': 'PV:3idd:scaler1.PR9',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan09_gate': {'source': 'PV:3idd:scaler1.G9',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan10_chname': {'source': 'PV:3idd:scaler1.NM10',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan10_preset': {'source': 'PV:3idd:scaler1.PR10',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan10_gate': {'source': 'PV:3idd:scaler1.G10',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan11_chname': {'source': 'PV:3idd:scaler1.NM11',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan11_preset': {'source': 'PV:3idd:scaler1.PR11',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan11_gate': {'source': 'PV:3idd:scaler1.G11',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan12_chname': {'source': 'PV:3idd:scaler1.NM12',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan12_preset': {'source': 'PV:3idd:scaler1.PR12',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan12_gate': {'source': 'PV:3idd:scaler1.G12',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan13_chname': {'source': 'PV:3idd:scaler1.NM13',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan13_preset': {'source': 'PV:3idd:scaler1.PR13',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan13_gate': {'source': 'PV:3idd:scaler1.G13',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan14_chname': {'source': 'PV:3idd:scaler1.NM14',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan14_preset': {'source': 'PV:3idd:scaler1.PR14',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan14_gate': {'source': 'PV:3idd:scaler1.G14',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan15_chname': {'source': 'PV:3idd:scaler1.NM15',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan15_preset': {'source': 'PV:3idd:scaler1.PR15',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan15_gate': {'source': 'PV:3idd:scaler1.G15',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan16_chname': {'source': 'PV:3idd:scaler1.NM16',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan16_preset': {'source': 'PV:3idd:scaler1.PR16',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan16_gate': {'source': 'PV:3idd:scaler1.G16',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan17_chname': {'source': 'PV:3idd:scaler1.NM17',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan17_preset': {'source': 'PV:3idd:scaler1.PR17',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan17_gate': {'source': 'PV:3idd:scaler1.G17',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan18_chname': {'source': 'PV:3idd:scaler1.NM18',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan18_preset': {'source': 'PV:3idd:scaler1.PR18',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan18_gate': {'source': 'PV:3idd:scaler1.G18',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan19_chname': {'source': 'PV:3idd:scaler1.NM19',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan19_preset': {'source': 'PV:3idd:scaler1.PR19',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan19_gate': {'source': 'PV:3idd:scaler1.G19',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan20_chname': {'source': 'PV:3idd:scaler1.NM20',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan20_preset': {'source': 'PV:3idd:scaler1.PR20',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan20_gate': {'source': 'PV:3idd:scaler1.G20',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan21_chname': {'source': 'PV:3idd:scaler1.NM21',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan21_preset': {'source': 'PV:3idd:scaler1.PR21',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan21_gate': {'source': 'PV:3idd:scaler1.G21',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan22_chname': {'source': 'PV:3idd:scaler1.NM22',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan22_preset': {'source': 'PV:3idd:scaler1.PR22',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan22_gate': {'source': 'PV:3idd:scaler1.G22',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan23_chname': {'source': 'PV:3idd:scaler1.NM23',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan23_preset': {'source': 'PV:3idd:scaler1.PR23',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan23_gate': {'source': 'PV:3idd:scaler1.G23',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan24_chname': {'source': 'PV:3idd:scaler1.NM24',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan24_preset': {'source': 'PV:3idd:scaler1.PR24',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan24_gate': {'source': 'PV:3idd:scaler1.G24',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan25_chname': {'source': 'PV:3idd:scaler1.NM25',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan25_preset': {'source': 'PV:3idd:scaler1.PR25',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan25_gate': {'source': 'PV:3idd:scaler1.G25',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan26_chname': {'source': 'PV:3idd:scaler1.NM26',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan26_preset': {'source': 'PV:3idd:scaler1.PR26',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan26_gate': {'source': 'PV:3idd:scaler1.G26',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan27_chname': {'source': 'PV:3idd:scaler1.NM27',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan27_preset': {'source': 'PV:3idd:scaler1.PR27',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan27_gate': {'source': 'PV:3idd:scaler1.G27',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan28_chname': {'source': 'PV:3idd:scaler1.NM28',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan28_preset': {'source': 'PV:3idd:scaler1.PR28',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan28_gate': {'source': 'PV:3idd:scaler1.G28',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan29_chname': {'source': 'PV:3idd:scaler1.NM29',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan29_preset': {'source': 'PV:3idd:scaler1.PR29',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan29_gate': {'source': 'PV:3idd:scaler1.G29',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan30_chname': {'source': 'PV:3idd:scaler1.NM30',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan30_preset': {'source': 'PV:3idd:scaler1.PR30',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan30_gate': {'source': 'PV:3idd:scaler1.G30',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan31_chname': {'source': 'PV:3idd:scaler1.NM31',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan31_preset': {'source': 'PV:3idd:scaler1.PR31',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan31_gate': {'source': 'PV:3idd:scaler1.G31',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_channels_chan32_chname': {'source': 'PV:3idd:scaler1.NM32',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None},
#      'scaler_channels_chan32_preset': {'source': 'PV:3idd:scaler1.PR32',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 0,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_channels_chan32_gate': {'source': 'PV:3idd:scaler1.G32',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['N', 'Y']},
#      'scaler_count_mode': {'source': 'PV:3idd:scaler1.CONT',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['OneShot', 'AutoCount']},
#      'scaler_delay': {'source': 'PV:3idd:scaler1.DLY',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_auto_count_delay': {'source': 'PV:3idd:scaler1.DLY1',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_freq': {'source': 'PV:3idd:scaler1.FREQ',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_preset_time': {'source': 'PV:3idd:scaler1.TP',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_auto_count_time': {'source': 'PV:3idd:scaler1.TP1',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': '',
#       'lower_ctrl_limit': 0.0,
#       'upper_ctrl_limit': 0.0},
#      'scaler_egu': {'source': 'PV:3idd:scaler1.EGU',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None}}},
#    'neat_stage_x': {'data': {'neat_stage_x_user_offset': 8.0,
#      'neat_stage_x_user_offset_dir': 1,
#      'neat_stage_x_velocity': 4.0,
#      'neat_stage_x_acceleration': 1.0,
#      'neat_stage_x_motor_egu': 'mm'},
#     'timestamps': {'neat_stage_x_user_offset': 1539893443.421373,
#      'neat_stage_x_user_offset_dir': 1539893443.421373,
#      'neat_stage_x_velocity': 1539893443.421373,
#      'neat_stage_x_acceleration': 1539893443.421373,
#      'neat_stage_x_motor_egu': 1539893443.421373},
#     'data_keys': {'neat_stage_x_user_offset': {'source': 'PV:3idd:m1.OFF',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': 'mm',
#       'lower_ctrl_limit': -1e+300,
#       'upper_ctrl_limit': 1e+300},
#      'neat_stage_x_user_offset_dir': {'source': 'PV:3idd:m1.DIR',
#       'dtype': 'integer',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['Pos', 'Neg']},
#      'neat_stage_x_velocity': {'source': 'PV:3idd:m1.VELO',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': 'mm/sec',
#       'lower_ctrl_limit': 0.2,
#       'upper_ctrl_limit': 0.0},
#      'neat_stage_x_acceleration': {'source': 'PV:3idd:m1.ACCL',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': 'sec',
#       'lower_ctrl_limit': -1e+300,
#       'upper_ctrl_limit': 1e+300},
#      'neat_stage_x_motor_egu': {'source': 'PV:3idd:m1.EGU',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None}}},
#    'mca': {'data': {'mca_preset_real_time': 0.25},
#     'timestamps': {'mca_preset_real_time': 1539893445.98804},
#     'data_keys': {'mca_preset_real_time': {'source': 'PV:3idd:mca1.PRTM',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 2,
#       'units': '',
#       'lower_ctrl_limit': -1e+300,
#       'upper_ctrl_limit': 1e+300}}},
#    'neat_stage_y': {'data': {'neat_stage_y_user_offset': 0.0,
#      'neat_stage_y_user_offset_dir': 1,
#      'neat_stage_y_velocity': 0.5,
#      'neat_stage_y_acceleration': 0.25,
#      'neat_stage_y_motor_egu': 'mm'},
#     'timestamps': {'neat_stage_y_user_offset': 1539893445.621373,
#      'neat_stage_y_user_offset_dir': 1539893445.621373,
#      'neat_stage_y_velocity': 1539893445.621373,
#      'neat_stage_y_acceleration': 1539893445.621373,
#      'neat_stage_y_motor_egu': 1539893445.621373},
#     'data_keys': {'neat_stage_y_user_offset': {'source': 'PV:3idd:m2.OFF',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': 'mm',
#       'lower_ctrl_limit': -1e+300,
#       'upper_ctrl_limit': 1e+300},
#      'neat_stage_y_user_offset_dir': {'source': 'PV:3idd:m2.DIR',
#       'dtype': 'integer',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None,
#       'enum_strs': ['Pos', 'Neg']},
#      'neat_stage_y_velocity': {'source': 'PV:3idd:m2.VELO',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': 'mm/sec',
#       'lower_ctrl_limit': 0.5,
#       'upper_ctrl_limit': 0.0},
#      'neat_stage_y_acceleration': {'source': 'PV:3idd:m2.ACCL',
#       'dtype': 'number',
#       'shape': [],
#       'precision': 3,
#       'units': 'sec',
#       'lower_ctrl_limit': -1e+300,
#       'upper_ctrl_limit': 1e+300},
#      'neat_stage_y_motor_egu': {'source': 'PV:3idd:m2.EGU',
#       'dtype': 'string',
#       'shape': [],
#       'units': None,
#       'lower_ctrl_limit': None,
#       'upper_ctrl_limit': None}}}},
#   'name': 'primary',
#   'hints': {'scaler': {'fields': ['Time',
#      'IC0_D',
#      'PIN',
#      'NaI',
#      'Fwd prompt',
#      'NFS delayed',
#      'NRIXS prompt',
#      'NRIXS Delayed']},
#    'neat_stage_x': {'fields': ['neat_stage_x']},
#    'mca': {'fields': []},
#    'neat_stage_y': {'fields': ['neat_stage_y']}},
#   'object_keys': {'scaler': ['Time',
#     'IC0_D',
#     'PIN',
#     'NaI',
#     'Fwd prompt',
#     'NFS delayed',
#     'NRIXS prompt',
#     'NRIXS Delayed',
#     'scaler_time'],
#    'neat_stage_x': ['neat_stage_x', 'neat_stage_x_user_setpoint'],
#    'mca': ['mca_preset_real_time', 'mca_elapsed_real_time', 'mca_spectrum'],
#    'neat_stage_y': ['neat_stage_y', 'neat_stage_y_user_setpoint']}}]

# %% [markdown]
# Seems be trouble creating ophyd object names with the data column names that have embedded whitespace.  These names come from the text in the scaler channel labels.  It was OK to acquire data with such names.
#
# **Looks like an assumption bug to me in the export code.**  Either of these places:
#
# * `databroker/headersource/core.py`
# * `databroker/headersource/sqlite.py`

# %%
list(h.events())[-1]
# Out:
# {'descriptor': '56aa28b1-621b-47ba-8d19-0ae05b30088e',
#  'uid': '7b898a27-fe32-4a21-b852-ae2537aa04cb',
#  'data': {'mca_preset_real_time': 0.25,
#   'mca_elapsed_real_time': 0.25,
#   'mca_spectrum': array([0, 0, 0, ..., 0, 0, 0]),
#   'Time': 2500000.0,
#   'IC0_D': 33.0,
#   'PIN': 1.0,
#   'NaI': 1.0,
#   'Fwd prompt': 0.0,
#   'NFS delayed': 0.0,
#   'NRIXS prompt': 0.0,
#   'NRIXS Delayed': 0.0,
#   'scaler_time': 0.25,
#   'neat_stage_y': 1.0,
#   'neat_stage_y_user_setpoint': 1.0,
#   'neat_stage_x': 4.0,
#   'neat_stage_x_user_setpoint': 4.0},
#  'timestamps': {'mca_preset_real_time': 1539893487.988774,
#   'mca_elapsed_real_time': 1539893487.988774,
#   'mca_spectrum': 1539893487.988774,
#   'Time': 1539893487.822108,
#   'IC0_D': 1539893487.822108,
#   'PIN': 1539893487.822108,
#   'NaI': 1539893487.822108,
#   'Fwd prompt': 1539893487.822108,
#   'NFS delayed': 1539893487.822108,
#   'NRIXS prompt': 1539893487.822108,
#   'NRIXS Delayed': 1539893487.822108,
#   'scaler_time': 1539893487.822108,
#   'neat_stage_y': 1539893477.638775,
#   'neat_stage_y_user_setpoint': 1539893477.638775,
#   'neat_stage_x': 1539893487.572108,
#   'neat_stage_x_user_setpoint': 1539893487.572108},
#  'time': 1539893488.0287702,
#  'seq_num': 12,
#  'filled': {}}
